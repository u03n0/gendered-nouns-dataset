# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from io import StringIO

# %%
response = requests.get('https://meta.wikimedia.org/wiki/Wiktionary#List_of_Wiktionaries')
soup = BeautifulSoup(response.text, 'html.parser')

# %%
table = soup.find('table')
df = pd.read_html(StringIO(str(table)))[0]
df
# Out:
#        №  Language Wiki  Entries  All pages     Edits  Admins    Users  \
# 0      1   English   en  7953694    9359597  78261263      82  4161083
# 1      2    French   fr  5037047    5639411  33598092      35   366969
# 2      3  Malagasy   mg  4135946    4198957  32654087       2    11759
# 3      4   Chinese   zh  1544311    2150792   8082669      10   118725
# 4      5     Greek   el  1491317    1547276   6629922      11    59890
# ..   ...       ...  ...      ...        ...       ...     ...      ...
# 163  164     Swati   ss      325       1364     10310       2     4034
# 164  165  Cherokee  chr      316       1287    778851       1    10426
# 165  166    Divehi   dv      230       1291      9209       1     2417
# 166  167  Tigrinya   ti      149       1175      9295       1     2308
# 167  168    Tswana   tn      131        982      8580       2     3629
#
#      Active users  Files
# 0            2327     21
# 1             527      6
# 2              32      3
# 3              77      1
# 4              76     23
# ..            ...    ...
# 163             4      0
# 164             6      1
# 165             2      2
# 166             1      0
# 167             2      0
#
# [168 rows x 10 columns]

# %%
languages = df.set_index('Language')['Wiki'].to_dict()
languages
# Out:
# {'English': 'en',
#  'French': 'fr',
#  'Malagasy': 'mg',
#  'Chinese': 'zh',
#  'Greek': 'el',
#  'Russian': 'ru',
#  'German': 'de',
#  'Kurdish': 'ku',
#  'Spanish': 'es',
#  'Swedish': 'sv',
#  'Serbo-Croatian': 'sh',
#  'Dutch': 'nl',
#  'Polish': 'pl',
#  'Lithuanian': 'lt',
#  'Hungarian': 'hu',
#  'Catalan': 'ca',
#  'Italian': 'it',
#  'Portuguese': 'pt',
#  'Finnish': 'fi',
#  'Tamil': 'ta',
#  'Japanese': 'ja',
#  'Turkish': 'tr',
#  'Ido': 'io',
#  'Armenian': 'hy',
#  'Korean': 'ko',
#  'Vietnamese': 'vi',
#  'Kannada': 'kn',
#  'Serbian': 'sr',
#  'Thai': 'th',
#  'Hindi': 'hi',
#  'Romanian': 'ro',
#  'Indonesian': 'id',
#  'Estonian': 'et',
#  'Norwegian': 'no',
#  'Saraiki': 'skr',
#  'Czech': 'cs',
#  'Malayalam': 'ml',
#  'Burmese': 'my',
#  'Limburgish': 'li',
#  'Uzbek': 'uz',
#  'Esperanto': 'eo',
#  'Odia': 'or',
#  'Telugu': 'te',
#  'Persian': 'fa',
#  'Sango': 'sg',
#  'Galician': 'gl',
#  'Occitan': 'oc',
#  'Arabic': 'ar',
#  'Icelandic': 'is',
#  'Javanese': 'jv',
#  'Asturian': 'ast',
#  'Ukrainian': 'uk',
#  'Azerbaijani': 'az',
#  'Basque': 'eu',
#  'Bangla': 'bn',
#  'Breton': 'br',
#  'Mon': 'mnw',
#  'Simple English': 'simple',
#  'Danish': 'da',
#  'Lao': 'lo',
#  'Latin': 'la',
#  'Shan': 'shn',
#  'Kabardian': 'kbd',
#  'Slovak': 'sk',
#  'Croatian': 'hr',
#  'Lombard': 'lmo',
#  'Walloon': 'wa',
#  'Fijian': 'fj',
#  'Kyrgyz': 'ky',
#  'Bulgarian': 'bg',
#  'Urdu': 'ur',
#  'Welsh': 'cy',
#  'Pashto': 'ps',
#  'Tajik': 'tg',
#  'Hebrew': 'he',
#  'Volapük': 'vo',
#  'Oromo': 'om',
#  'Slovenian': 'sl',
#  'Afrikaans': 'af',
#  'Malay': 'ms',
#  'Minnan': 'zh-min-nan',
#  'Sicilian': 'scn',
#  'Tagalog': 'tl',
#  'Punjabi': 'pa',
#  'Georgian': 'ka',
#  'Western Frisian': 'fy',
#  'Swahili': 'sw',
#  'Kazakh': 'kk',
#  'Norwegian Nynorsk': 'nn',
#  'Minangkabau': 'min',
#  'Latvian': 'lv',
#  'Gorontalo': 'gor',
#  'Low German': 'nds',
#  'Albanian': 'sq',
#  'Luxembourgish': 'lb',
#  'Bosnian': 'bs',
#  'Corsican': 'co',
#  'Mongolian': 'mn',
#  'Western Punjabi': 'pnb',
#  'Cantonese': 'zh-yue',
#  'Nāhuatl': 'nah',
#  'Zazaki': 'diq',
#  'Sanskrit': 'sa',
#  'Khmer': 'km',
#  'Belarusian': 'be',
#  'Nias': 'nia',
#  'Venetian': 'vec',
#  'Turkmen': 'tk',
#  'Macedonian': 'mk',
#  'Samoan': 'sm',
#  'Upper Sorbian': 'hsb',
#  'Kashmiri': 'ks',
#  'Shawiya': 'shy',
#  'Central Bikol': 'bcl',
#  'Sundanese': 'su',
#  'Irish': 'ga',
#  'Batak Mandailing': 'btm',
#  'Central Kurdish': 'ckb',
#  'Scottish Gaelic': 'gd',
#  'Aragonese': 'an',
#  'Goan Konkani': 'gom',
#  'Hausa': 'ha',
#  'Marathi': 'mr',
#  'Wolof': 'wo',
#  'Manipuri': 'mni',
#  "Pa'O": 'blk',
#  'Banjar': 'bjn',
#  'Interlingua': 'ia',
#  'Somali': 'so',
#  'Sinhala': 'si',
#  'Old English': 'ang',
#  'Maltese': 'mt',
#  'Sindhi': 'sd',
#  'Tatar': 'tt',
#  'Faroese': 'fo',
#  'Guarani': 'gn',
#  'Interlingue': 'ie',
#  'Māori': 'mi',
#  'Kashubian': 'csb',
#  'Uyghur': 'ug',
#  'Gun': 'guw',
#  'Southern Sotho': 'st',
#  'Lojban': 'jbo',
#  'Fiji Hindi': 'hif',
#  'Aromanian': 'roa-rup',
#  'Kalaallisut': 'kl',
#  'Zulu': 'zu',
#  'Aymara': 'ay',
#  'Lingala': 'ln',
#  'Tyap': 'kcg',
#  'Yiddish': 'yi',
#  'Gujarati': 'gu',
#  'Nauru': 'na',
#  'Manx': 'gv',
#  'Cornish': 'kw',
#  'Tok Pisin': 'tpi',
#  'Amharic': 'am',
#  'Nepali': 'ne',
#  'Kinyarwanda': 'rw',
#  'Tsonga': 'ts',
#  'Igbo': 'ig',
#  'Quechua': 'qu',
#  'Inuktitut': 'iu',
#  'Swati': 'ss',
#  'Cherokee': 'chr',
#  'Divehi': 'dv',
#  'Tigrinya': 'ti',
#  'Tswana': 'tn'}
